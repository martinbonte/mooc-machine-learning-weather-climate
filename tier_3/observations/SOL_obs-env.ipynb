# %% [markdown]
# <center><h1>My version of this notebook of the ECMWF MOOC</h1></center>
#   <p style="margin-bottom:1.5cm;"> </p>
# <center><font size="8"><strong>SOLUTIONS</strong></font></center>

# %% [markdown]
# <font size=5>My codes to solve the proposed exercices are [here](obs-env.ipynb#improving_decision_tree_regressor), [there](obs-env.ipynb#handling_missing_values) and [there](obs_env.ipynb#NBEATS).</font>
#
# Below is the beginning of the original notebook provided in the context of the ECMWF MOOC on machine learning in weather and climate.

# %% [markdown]
# Welcome to this notebook! If you're new to Python, don't worry, this notebook is designed to help you get familiar with some concepts of Machine Learning. You can simply run the script to see how it works. On the other hand, if you're familiar with Python, feel free to change the parameters to better understand how it works.
#
# Whether you're a beginner or an experienced user, we hope you find this notebook informative and helpful.

# %% [markdown]
# # Setup
#
# ## - Working locally
# If you're running this notebook locally, you might need to create a proper conda environment using the file "environment.yml":
# - conda env create -f environment.yml (the first line of the yml file sets the new environment's name.)
# - conda activate myenv (the environment's name)
# - conda install -c anaconda ipykernel
# - python -m ipykernl install --user --name=myenv
#
# Using the above command, you will have the appropriate conda environment in your Jupyter notebook.
# ![kernel](adding_conda_kernel.jpeg)

# %% [markdown]
# Change the kernel to be your new environement: 'mooc_ntbk' if you kept the default name.
# Please consider running the cell below to handle some version conflicts.

# %%
#--------------------------------------# 
# Fix python path of working locally   #
#--------------------------------------#
from utils import fix_pythonpath_if_working_locally
fix_pythonpath_if_working_locally()

# %%
path = './data/'

# %% [markdown]
# ## - Running the tutorial via free cloud platforms

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_3/observations/obs-env.ipynb)

# %% [markdown]
# First, let's install and import some useful libraries/modules.

# %%
#--------------------------#
# Install some libraries   #
#--------------------------#
# !pip install openturns darts matplotlib==3.6.3

# MATPLOTLIB VERSION NEEDS TO BE 3.6.3
# Out:
# Requirement already satisfied: openturns in /home/martin/anaconda3/lib/python3.9/site-packages (1.20.post3)
# Collecting darts
#   Using cached darts-0.24.0-py3-none-any.whl (693 kB)
# Collecting matplotlib==3.6.3
#   Downloading matplotlib-3.6.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 9.9 MB/s eta 0:00:000m eta 0:00:010:00:01
# Requirement already satisfied: contourpy>=1.0.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from matplotlib==3.6.3) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/martin/anaconda3/lib/python3.9/site-packages (from matplotlib==3.6.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from matplotlib==3.6.3) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from matplotlib==3.6.3) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in /home/martin/anaconda3/lib/python3.9/site-packages (from matplotlib==3.6.3) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from matplotlib==3.6.3) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from matplotlib==3.6.3) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from matplotlib==3.6.3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/martin/anaconda3/lib/python3.9/site-packages (from matplotlib==3.6.3) (2.8.2)
# Requirement already satisfied: dill in /home/martin/anaconda3/lib/python3.9/site-packages (from openturns) (0.3.6)
# Requirement already satisfied: psutil in /home/martin/anaconda3/lib/python3.9/site-packages (from openturns) (5.9.5)
# Collecting catboost>=1.0.6 (from darts)
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 8.6 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting holidays>=0.11.1 (from darts)
#   Using cached holidays-0.23-py3-none-any.whl (485 kB)
# Requirement already satisfied: joblib>=0.16.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from darts) (1.2.0)
# Collecting lightgbm>=3.2.0 (from darts)
#   Using cached lightgbm-3.3.5-py3-none-manylinux1_x86_64.whl (2.0 MB)
# Collecting nfoursid>=1.0.0 (from darts)
#   Using cached nfoursid-1.0.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: pandas>=1.0.5 in /home/martin/anaconda3/lib/python3.9/site-packages (from darts) (2.0.0)
# Collecting pmdarima>=1.8.0 (from darts)
#   Downloading pmdarima-2.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 9.9 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting prophet>=1.1.1 (from darts)
#   Using cached prophet-1.1.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.9 MB)
# Collecting pyod>=0.9.5 (from darts)
#   Using cached pyod-1.0.9.tar.gz (149 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.22.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from darts) (2.28.2)
# Requirement already satisfied: scikit-learn>=1.0.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from darts) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/martin/anaconda3/lib/python3.9/site-packages (from darts) (1.10.1)
# Collecting shap>=0.40.0 (from darts)
#   Downloading shap-0.41.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 kB 8.5 MB/s eta 0:00:0031m11.6 MB/s eta 0:00:01
# Collecting statsforecast>=1.4 (from darts)
#   Using cached statsforecast-1.5.0-py3-none-any.whl (99 kB)
# Collecting statsmodels>=0.13.0 (from darts)
#   Downloading statsmodels-0.13.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 9.8 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting tbats>=1.1.0 (from darts)
#   Using cached tbats-1.1.3-py3-none-any.whl (44 kB)
# Requirement already satisfied: tqdm>=4.60.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from darts) (4.65.0)
# Requirement already satisfied: xarray>=0.17.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from darts) (2022.11.0)
# Collecting xgboost>=1.6.0 (from darts)
#   Using cached xgboost-1.7.5-py3-none-manylinux2014_x86_64.whl (200.3 MB)
# Requirement already satisfied: pytorch-lightning>=1.5.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from darts) (2.0.0)
# Requirement already satisfied: tensorboardX>=2.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from darts) (2.6)
# Requirement already satisfied: torch>=1.8.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from darts) (1.13.1)
# Requirement already satisfied: graphviz in /home/martin/anaconda3/lib/python3.9/site-packages (from catboost>=1.0.6->darts) (0.20.1)
# Collecting plotly (from catboost>=1.0.6->darts)
#   Using cached plotly-5.14.1-py2.py3-none-any.whl (15.3 MB)
# Requirement already satisfied: six in /home/martin/anaconda3/lib/python3.9/site-packages (from catboost>=1.0.6->darts) (1.16.0)
# Collecting convertdate>=2.3.0 (from holidays>=0.11.1->darts)
#   Using cached convertdate-2.4.0-py3-none-any.whl (47 kB)
# Collecting hijri-converter (from holidays>=0.11.1->darts)
#   Using cached hijri_converter-2.2.4-py3-none-any.whl (14 kB)
# Collecting korean-lunar-calendar (from holidays>=0.11.1->darts)
#   Using cached korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: wheel in /home/martin/anaconda3/lib/python3.9/site-packages (from lightgbm>=3.2.0->darts) (0.38.4)
# Requirement already satisfied: pytz>=2020.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.5->darts) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.5->darts) (2023.3)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima>=1.8.0->darts)
#   Downloading Cython-0.29.34-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 9.2 MB/s eta 0:00:0011.1 MB/s eta 0:00:01
# Requirement already satisfied: urllib3 in /home/martin/anaconda3/lib/python3.9/site-packages (from pmdarima>=1.8.0->darts) (1.26.15)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from pmdarima>=1.8.0->darts) (67.6.1)
# Collecting cmdstanpy>=1.0.4 (from prophet>=1.1.1->darts)
#   Using cached cmdstanpy-1.1.0-py3-none-any.whl (83 kB)
# Collecting LunarCalendar>=0.0.9 (from prophet>=1.1.1->darts)
#   Using cached LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting numba>=0.51 (from pyod>=0.9.5->darts)
#   Downloading numba-0.56.4-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 10.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: PyYAML>=5.4 in /home/martin/anaconda3/lib/python3.9/site-packages (from pytorch-lightning>=1.5.0->darts) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from pytorch-lightning>=1.5.0->darts) (2023.4.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from pytorch-lightning>=1.5.0->darts) (0.11.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from pytorch-lightning>=1.5.0->darts) (4.5.0)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from pytorch-lightning>=1.5.0->darts) (0.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/martin/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->darts) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/martin/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->darts) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/martin/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->darts) (2022.12.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from scikit-learn>=1.0.1->darts) (3.1.0)
# Collecting slicer==0.0.7 (from shap>=0.40.0->darts)
#   Using cached slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: cloudpickle in /home/martin/anaconda3/lib/python3.9/site-packages (from shap>=0.40.0->darts) (2.2.1)
# Collecting plotly-resampler (from statsforecast>=1.4->darts)
#   Using cached plotly_resampler-0.8.3.2.tar.gz (46 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fugue>=0.8.1 (from statsforecast>=1.4->darts)
#   Using cached fugue-0.8.3-py3-none-any.whl (372 kB)
# Collecting patsy>=0.5.2 (from statsmodels>=0.13.0->darts)
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from tensorboardX>=2.1->darts) (3.19.6)
# Collecting pymeeus<=1,>=0.3.13 (from convertdate>=2.3.0->holidays>=0.11.1->darts)
#   Using cached PyMeeus-0.5.12.tar.gz (5.8 MB)
#   Preparing metadata (setup.py) ... done
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts)
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting triad>=0.8.4 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Using cached triad-0.8.6-py3-none-any.whl (77 kB)
# Collecting adagio>=0.2.4 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Using cached adagio-0.2.4-py3-none-any.whl (26 kB)
# Collecting qpd>=0.4.0 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Using cached qpd-0.4.1-py3-none-any.whl (187 kB)
# Collecting fugue-sql-antlr>=0.1.6 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Using cached fugue-sql-antlr-0.1.6.tar.gz (154 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyarrow>=0.15.1 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading pyarrow-11.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 9.0 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting pandas>=1.0.5 (from darts)
#   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 10.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting sqlglot (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Using cached sqlglot-11.5.5-py3-none-any.whl (246 kB)
# Requirement already satisfied: jinja2 in /home/martin/anaconda3/lib/python3.9/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (3.1.2)
# Collecting ephem>=3.7.5.3 (from LunarCalendar>=0.0.9->prophet>=1.1.1->darts)
#   Downloading ephem-4.1.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.6 MB/s eta 0:00:0031m11.7 MB/s eta 0:00:01
# Collecting llvmlite<0.40,>=0.39.0dev0 (from numba>=0.51->pyod>=0.9.5->darts)
#   Downloading llvmlite-0.39.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 9.4 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting numpy>=1.19 (from matplotlib==3.6.3)
#   Downloading numpy-1.23.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 9.8 MB/s eta 0:00:000m eta 0:00:010:01:01
# Collecting tenacity>=6.2.0 (from plotly->catboost>=1.0.6->darts)
#   Using cached tenacity-8.2.2-py3-none-any.whl (24 kB)
# Collecting dash<3.0.0,>=2.2.0 (from plotly-resampler->statsforecast>=1.4->darts)
#   Using cached dash-2.9.3-py3-none-any.whl (10.2 MB)
# Collecting jupyter-dash>=0.4.2 (from plotly-resampler->statsforecast>=1.4->darts)
#   Using cached jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting orjson<4.0.0,>=3.8.0 (from plotly-resampler->statsforecast>=1.4->darts)
#   Downloading orjson-3.8.10-cp39-cp39-manylinux_2_28_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 11.1 MB/s eta 0:00:00
# Collecting trace-updater>=0.0.8 (from plotly-resampler->statsforecast>=1.4->darts)
#   Using cached trace_updater-0.0.9.1-py3-none-any.whl (185 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (22.2.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts)
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 8.4 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts)
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts)
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: frozenlist>=1.1.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/martin/anaconda3/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.3.1)
# Collecting Flask>=1.0.4 (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Using cached Flask-2.2.3-py3-none-any.whl (101 kB)
# Collecting dash-html-components==2.0.0 (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting antlr4-python3-runtime<4.12,>=4.11.1 (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast>=1.4->darts)
#   Using cached antlr4_python3_runtime-4.11.1-py3-none-any.whl (144 kB)
# Collecting retrying (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts)
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: ipython in /home/martin/anaconda3/lib/python3.9/site-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (8.12.0)
# Requirement already satisfied: ipykernel in /home/martin/anaconda3/lib/python3.9/site-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (6.22.0)
# Collecting ansi2html (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts)
#   Using cached ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: nest-asyncio in /home/martin/anaconda3/lib/python3.9/site-packages (from jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (1.5.6)
# Collecting fs (from triad>=0.8.4->fugue>=0.8.1->statsforecast>=1.4->darts)
#   Using cached fs-2.4.16-py2.py3-none-any.whl (135 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from jinja2->fugue>=0.8.1->statsforecast>=1.4->darts) (2.1.2)
# Collecting Werkzeug>=2.2.2 (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 9.2 MB/s eta 0:00:00
# Collecting itsdangerous>=2.0 (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts)
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: click>=8.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (8.1.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (6.5.0)
# Collecting appdirs~=1.4.3 (from fs->triad>=0.8.4->fugue>=0.8.1->statsforecast>=1.4->darts)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: comm>=0.1.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (7.3.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.1.6)
# Requirement already satisfied: pyzmq>=20 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (6.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (5.9.0)
# Requirement already satisfied: backcall in /home/martin/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.2.0)
# Requirement already satisfied: decorator in /home/martin/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.18.2)
# Requirement already satisfied: pickleshare in /home/martin/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (2.15.1)
# Requirement already satisfied: stack-data in /home/martin/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/martin/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (4.8.0)
# Requirement already satisfied: zipp>=0.5 in /home/martin/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler->statsforecast>=1.4->darts) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.8.3)
# Requirement already satisfied: entrypoints in /home/martin/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/martin/anaconda3/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (3.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/martin/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.7.0)
# Requirement already satisfied: wcwidth in /home/martin/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (2.2.1)
# Requirement already satisfied: pure-eval in /home/martin/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->jupyter-dash>=0.4.2->plotly-resampler->statsforecast>=1.4->darts) (0.2.2)
# Building wheels for collected packages: pyod, plotly-resampler, fugue-sql-antlr, pymeeus
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.0.9-py3-none-any.whl size=184097 sha256=0a30354642c450a8ed23878e4396564e95398cf0e6ff2b4dfb755797b9a20dcf
#   Stored in directory: /home/martin/.cache/pip/wheels/1b/9c/b8/9759d7cc64a1e01bb9872ade80cb7db445ccf506e083325106
#   Building wheel for plotly-resampler (pyproject.toml) ... done
#   Created wheel for plotly-resampler: filename=plotly_resampler-0.8.3.2-cp39-cp39-manylinux_2_31_x86_64.whl size=53633 sha256=62c3efb9ed90ca04ad2055118a1cc61ce1a6c0352084d474c03adbc0f1e404e0
#   Stored in directory: /home/martin/.cache/pip/wheels/9e/36/06/4c11e300918011376af149098621ec7ebe06d8256566d43d51
#   Building wheel for fugue-sql-antlr (setup.py) ... done
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.1.6-py3-none-any.whl size=158049 sha256=4a54d233054b2f11c7a75c5aae83f6fa9570bf0ff4ae87b8f77e916d48b32da6
#   Stored in directory: /home/martin/.cache/pip/wheels/57/b3/01/795c8a9ccaf9574fc3471b0199731c5526cf7c5e127db42a74
#   Building wheel for pymeeus (setup.py) ... done
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=731999 sha256=a982e33d6d65d2dbce9d2086b8950eefc64f5e1f7d5f2ff618119ad3f357cd37
#   Stored in directory: /home/martin/.cache/pip/wheels/04/1f/e5/8dd0c661cd8d252817655dc14a84f7ae045d6616594145aa81
# Successfully built pyod plotly-resampler fugue-sql-antlr pymeeus
# Installing collected packages: trace-updater, sqlglot, pymeeus, korean-lunar-calendar, ephem, dash-table, dash-html-components, dash-core-components, appdirs, antlr4-python3-runtime, Werkzeug, tenacity, slicer, retrying, orjson, numpy, multidict, llvmlite, itsdangerous, hijri-converter, fs, Cython, convertdate, async-timeout, ansi2html, yarl, pyarrow, plotly, patsy, pandas, numba, LunarCalendar, holidays, Flask, xgboost, triad, statsmodels, matplotlib, dash, cmdstanpy, aiohttp, shap, pyod, prophet, pmdarima, nfoursid, lightgbm, fugue-sql-antlr, catboost, adagio, tbats, qpd, jupyter-dash, plotly-resampler, fugue, statsforecast, darts
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.2
#     Uninstalling numpy-1.24.2:
#       Successfully uninstalled numpy-1.24.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.0
#     Uninstalling pandas-2.0.0:
#       Successfully uninstalled pandas-2.0.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires wrapt>=1.11.0, which is not installed.
# Successfully installed Cython-0.29.34 Flask-2.2.3 LunarCalendar-0.0.9 Werkzeug-2.2.3 adagio-0.2.4 aiohttp-3.8.4 ansi2html-1.8.0 antlr4-python3-runtime-4.11.1 appdirs-1.4.4 async-timeout-4.0.2 catboost-1.1.1 cmdstanpy-1.1.0 convertdate-2.4.0 darts-0.24.0 dash-2.9.3 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 ephem-4.1.4 fs-2.4.16 fugue-0.8.3 fugue-sql-antlr-0.1.6 hijri-converter-2.2.4 holidays-0.23 itsdangerous-2.1.2 jupyter-dash-0.4.2 korean-lunar-calendar-0.3.1 lightgbm-3.3.5 llvmlite-0.39.1 matplotlib-3.6.3 multidict-6.0.4 nfoursid-1.0.1 numba-0.56.4 numpy-1.23.5 orjson-3.8.10 pandas-1.5.3 patsy-0.5.3 plotly-5.14.1 plotly-resampler-0.8.3.2 pmdarima-2.0.3 prophet-1.1.2 pyarrow-11.0.0 pymeeus-0.5.12 pyod-1.0.9 qpd-0.4.1 retrying-1.3.4 shap-0.41.0 slicer-0.0.7 sqlglot-11.5.5 statsforecast-1.5.0 statsmodels-0.13.5 tbats-1.1.3 tenacity-8.2.2 trace-updater-0.0.9.1 triad-0.8.6 xgboost-1.7.5 yarl-1.8.2

# %%
#--------------------------#
# Check matplotlib version #
#--------------------------#
import matplotlib
matplotlib.__version__
# Out:
# '3.6.3'

# %% [markdown]
# If at this stage the matplotlib version is not 3.6.3, go to 'Runtime' and press 'restart runtime' and execute again the cell above.

# %%
#-----------------------------# 
# Import external libraries   #
#-----------------------------#
import os
import sys

import numpy as np 
import pandas as pd

import openturns as ot
from openturns.viewer import View

import sklearn
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn import linear_model

from darts.utils.statistics import check_seasonality, plot_acf, TimeSeries
from darts.dataprocessing.transformers import Scaler
from darts.models import NBEATSModel, ExponentialSmoothing, Prophet, RNNModel
from darts.utils.timeseries_generation import datetime_attribute_timeseries
from darts.metrics import mape

import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
plt.rcParams['figure.figsize'] = [12, 7]

import datetime, time

import logging
logging.disable(logging.CRITICAL)
import warnings
warnings.simplefilter('ignore')
warnings.filterwarnings("ignore")

# %%
#----------------------# 
# Download data        #
#----------------------#
# !wget https://github.com/ecmwf-projects/mooc-machine-learning-weather-climate/raw/main/tier_3/observations/data.zip
# Out:
# --2023-04-23 17:38:11--  https://github.com/ecmwf-projects/mooc-machine-learning-weather-climate/raw/main/tier_3/observations/data.zip
# Résolution de github.com (github.com)… 140.82.121.4
# Connexion à github.com (github.com)|140.82.121.4|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/ecmwf-projects/mooc-machine-learning-weather-climate/main/tier_3/observations/data.zip [suivant]
# --2023-04-23 17:38:11--  https://raw.githubusercontent.com/ecmwf-projects/mooc-machine-learning-weather-climate/main/tier_3/observations/data.zip
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 597527 (584K) [application/zip]
# Enregistre : «data.zip.3»
#
# data.zip.3          100%[===================>] 583,52K  1,81MB/s    ds 0,3s
#
# 2023-04-23 17:38:12 (1,81 MB/s) - «data.zip.3» enregistré [597527/597527]

# %%
# Unzip the data
# !unzip data.zip
# Out:
# Archive:  data.zip
# replace data/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %% [markdown]
# # 1) Generating perturbations to account for uncertainties in discharge observations
#
# All observations have some degree of uncertainty associated with them, whether it be due to measurement errors, variability in the system being observed, or other factors. By quantifying this uncertainty we can account for the limitations of the data and to appropriately interpret the results of our analysis. It also helps to identify areas where further data collection or analysis may be needed to reduce uncertainty and improve the reliability of our conclusions.
#
# ## a. Discharge observation data
# Discharge observations during a flood event can be obtained through various methods including:
#
# - Stream gauges: Physical instruments installed along rivers or streams that measure the flow of water.
#
# - Remote sensing: Use of satellite imagery and other aerial technologies to estimate discharge from above.
#
# - Numerical models: Predictive simulations that use historical data and real-time weather data to estimate discharge.
#
# - Field measurements: Direct measurement of water flow velocity and cross-sectional area to estimate discharge.

# %%
path = './data/'

# %%
#--------------------------------#
# Read data                      #
#--------------------------------#
# Read a hydrograph of a flood event of ~8 days. The data is hourly
filename = 'hydrograph.txt'
n_skipLine = 1 
qt = ot.Sample.ImportFromTextFile(os.path.join(path, filename), ' ', n_skipLine)
t = qt.getMarginal(0) #time in sec, ref date is 04/02/1981 at 6:00am
q = qt.getMarginal(1)

tdate = pd.date_range(start='2/4/1981 6H', periods=len(qt), freq='H')

plt.plot(tdate, q, color='blue')
plt.xlabel("Date")
plt.ylabel("Discharge [m$^3$s$^{-1}$]")
plt.title('Hydrograph in the upstream station \n of a catchment during a flood event')
# Out:
# Text(0.5, 1.0, 'Hydrograph in the upstream station \n of a catchment during a flood event')

# %% [markdown]
# Discharge observations are uncertain due to several factors, including:
#
# - Measurement error: Discharge measurements can be affected by measurement error, such as the accuracy of the measurement device or the presence of debris in the river that can block the device. This can result in readings that are higher or lower than the actual discharge.
#
# - Channel changes: Changes to the river channel, such as sediment deposition or erosion, can alter the relationship between stage (water level) and discharge. This can result in discharge observations that are not accurate or reliable.
#
# - Inadequate data: In some cases, discharge observations may not be available for all periods of interest, or the data may be sparse or of low quality. This can result in significant uncertainty in the discharge observations.
#
# - Interpolation and extrapolation: In some cases, discharge observations may need to be interpolated or extrapolated to estimate discharge at ungauged locations or over longer periods of time. This can result in additional uncertainty in the discharge observations.
#
# These are just a few examples of why discharge observations can be uncertain. It is important to understand the sources of uncertainty in discharge observations and to use appropriate methods to account for this uncertainty when analyzing and using discharge data. In our case, we will consider ensemble methods by perturbing the hydrograph to account for uncertainties.
#
# ## b. Discharge perturbations

# %% [markdown]
# To create realistic perturbations, we use the covariance to model the relationship between discharge at different timesteps.
#
# The covariance model of a time series is a statistical model that describes the dependence structure of the series over time. In particular, the covariance model specifies the relationship between the mean and variance of the series as well as the correlation between observations at different points in time. The covariance between two observations at times $t$ and $s$ is defined as:
#
# $Cov(X_t, X_s) = E[(X_t - μ_t)(X_s - μ_s)]$
#
# where $X_t$ and $X_s$ are the values of the time series at times $t$ and $s$, $μ_t$ and $μ_s$ are the means of the time series at times $t$ and $s$, and $E$ is the expected value operator.
#
# The covariance model of a time series assumes that the time series is stationary, meaning that its statistical properties do not change over time. Under this assumption, the covariance between two observations only depends on the time lag between them, and not on the specific time points at which they occur. In other words, the covariance between $X_t$ and $X_s$ only depends on the time difference $|t-s|$.

# %%
#-----------------------------------------#
# Define the temporal grid accoring to    # 
# the timesteps defined in the hydrograph #
#-----------------------------------------#
myTimeGrid = ot.RegularGrid(np.min(t), t[1, 0] - t[0, 0], t.getSize())
graph = myTimeGrid.draw()
graph.setTitle("Regular temporal grid")
view = ot.viewer.View(graph)

#----------------------------------------------------------------#
# Identify the time series with a Polynomial Chaos Expansion     #
#----------------------------------------------------------------#
max_poly_degree = 25
ot.ResourceMap.SetAsUnsignedInteger("FunctionalChaosAlgorithm-MaximumTotalDegree", max_poly_degree)
algo = ot.FunctionalChaosAlgorithm(t, q)
algo.run()
trend = algo.getResult().getMetaModel()

#-------------------------------------------------------#
# Calibrate the covariance model using expert knowledge #
#-------------------------------------------------------# 
# The Matern covariance function is commonly used as a kernel function in a Gaussian Process.
amplitude = [200] # We assume that, on average, the difference of discharge between two observations is 200 m3/s
scale = [86400] # We assume that the correlation length is of 1 day
nu = 5/2
covarianceModel = ot.MaternModel(scale, amplitude, nu)

#------------------------------------------------------------------#
# Create a Gaussian process to get realizations past the last time #
#------------------------------------------------------------------#
process = ot.GaussianProcess(ot.TrendTransform(trend, myTimeGrid), covarianceModel, myTimeGrid)
nb = 100 # number of desired perturbations
sample = process.getSample(nb)
g = sample.drawMarginal(0)
g.setColors(["gray"]) # Perturbations are plotted in solid gray lines
c = trend.draw(myTimeGrid.getVertices()[0], myTimeGrid.getVertices()[-1]).getDrawable(0) 
c.setLineStyle("dashed") 
c.setColor("darkgreen") # Polynomial model is plotted in dashed green line
g.add(c)
g.add(ot.Curve(t,q)) # Observed discharge in blue
g.setTitle("Hydrograph perturbations")
ot.Show(g)
# Out:
# E20230428 22:55:57.914928  9822 trust_region_minimizer.cc:95] Terminating: Number of consecutive invalid steps more than Solver::Options::max_num_consecutive_invalid_steps: 5
# WRN - Switch to finite difference to compute the gradient at point=[818248,-25.8623,-0.000135101]
# WRN - TNC went to an abnormal point x=[nan,nan,nan] y=[] msg=TNC got a nan input value

# %% [markdown]
# - Perturbations were generated using a Gaussian process model.
# - To construct a Gaussian process model, we need to specify the mean and and the covariance of the process.
# - Polynomial Chaos expansion model was used to fit the observed discharge. Its mean/trend was considered to be the mean of the Gaussian process.
# - The covariance of the Gaussian process, in our case, was constructed based on the hydrologist judgement.

# %% [markdown]
# ###  <div class="alert-danger"> Q1) How does the hydrograph perturbation change according to: Amplitude? Scale? Maximum polynomial degree? </div>

# %% [markdown]
# # 2) Predictive model of the water level at a station given the Strickler coefficient at this station and the discharge at the upstream area
#
# Now, let's build a surrogate model that predicts the water level timeseries in a station in the middle of the catchment given the Strickler coefficient in this station and the discharge in the upstream station at a given timestep. The Strickler coefficient reflects the roughness of the bottom of the river at a given location.
#
# The size of the input training data is 1,000 members. They are derived from a perturbation procedure similar to the one described above. The input data contain the upstream discharge (x_train[:,0]) and the Strickler coefficient (x_train[:,1]). The different outputs of the hydrodynamic model are grouped in the output training data and describe a timeseries (52 timesteps) of the water height at a station located in the middle of the catchment.
#
# The size of the test file is 500 members. The test file and the training file were constructed independently.

# %%
#------------------#
# Upload data      #
#-----------------# 
### Training data
x_train = np.load(os.path.join(path, 'x_train.npy'))
y_train = np.load(os.path.join(path, 'y_train.npy'))

### Test data
x_test = np.load(os.path.join(path, 'x_test.npy'))
y_test = np.load(os.path.join(path, 'y_test.npy'))

print("The size of the training sample is: {:d}".format(x_train.shape[0]))
print("The size of the test sample is: {:d}".format(x_test.shape[0]))
print("Number of features is: {:d}".format(x_train.shape[1]))
# Out:
# The size of the training sample is: 1000
# The size of the test sample is: 500
# Number of features is: 2

# %%
#------------------#
# Visualise data   #
#------------------# 
### Before diving into constructing the surrogate model, one necessary step is: Data visualisation

# plot the max and min of the simulation according to the last timestep
simu_max = np.argmax((y_train[:][-1]))
plt.plot(y_train[simu_max], c='red')
plt.text(y_train.shape[1], y_train[simu_max][-1], x_train[simu_max], fontsize=8, c='red') 

simu_min = np.argmin((y_train[:][-1]))
plt.plot(y_train[simu_min], c='blue')
plt.text(y_train.shape[1], y_train[simu_min][-1], x_train[simu_min], fontsize=8, c='blue') 

plt.grid()
plt.xlabel('Timestep')
plt.ylabel('Water level [m]')
plt.grid(alpha=0.5)
plt.show()

# %%
# plot changes in the water level in the last timestep accriding to the discharge and the Strickler coefficient
x = x_train[:,0]
y = x_train[:,1]

timestep = -1 # last time step 
z = y_train[:,timestep]

fig = plt.figure(figsize=(10, 6))
plt.scatter(x, y,
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = z*10,
           c=z)
plt.xlabel('Upstream discharge [$m^3s^{-1}$]')
plt.ylabel('Strickler coefficient [$m^{1/3}s^{-1}$]')

clb = plt.colorbar()
clb.ax.set_title('Water level [$m$]', fontsize=7)
plt.show()

# %% [markdown]
# Let's build a Decision Tree regressor model to mimic the behaviour of the hydrodynamic model to speed up this latter.
#
# A Decision Tree Regressor is a supervised learning algorithm that is used for regression tasks. The algorithm builds a tree-like model of decisions and their possible consequences, where each internal node represents a test on an attribute, each branch represents the outcome of the test, and each leaf node represents a prediction for the target variable.
#
# The Decision Tree algorithm works by recursively splitting the data into subsets based on the values of a selected attribute. The attribute with the highest predictive power is selected as the root node of the tree, and the data is split based on its values. The process is repeated for each subset until the leaf nodes are reached, where the prediction is made for the target variable.
#
# The goal of the Decision Tree regressor is to minimize the variance of the target variable within each leaf node while maximizing the difference in the means between different leaf nodes. This is achieved by selecting the optimal split point for each node based on the variance reduction criterion, such as the mean squared error (MSE) or mean absolute error (MAE).
#
# For more information, please check: https://scikit-learn.org/stable/modules/tree.html#tree

# %%
#------------------------------#
# Train a DecisionTree model   #
#------------------------------# 
### Constructing a surrogate model
rf = DecisionTreeRegressor()
training_start_time = time.process_time() #CPU time
rf_model = rf.fit(x_train, y_train)
print(f'CPU time for training is: {time.process_time() - training_start_time}')
test_start_time = time.process_time()
y_pred = rf_model.predict(x_test)
print(f'CPU time for test is: {time.process_time() - test_start_time}')
# If you want to measure wall clock time instead, use time.time()

### How good are the predictions?
q2_score = r2_score(y_pred, y_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("The R2 score on test set: {:.4f}".format(q2_score))
print("The root mean squared error (RMSE) on test set: {:.4f} [m]".format(rmse))
# Out:
# CPU time for training is: 0.020072658000000132
# CPU time for test is: 0.0011288750000009173
# The R2 score on test set: 0.8451
# The root mean squared error (RMSE) on test set: 0.3041 [m]

# %%
#------------------------------------#
# Visualise the DecisionTree model   #
#------------------------------------# 
plot = False # Visualise the decision tree as plot; it takes time and the generated plot is not readable 
if plot:
    fig = plt.figure(figsize=(25,20)) 
    _ = tree.plot_tree(rf, filled=True)
text_representation = tree.export_text(rf) # Visualise the decision tree as text 
print(text_representation)
# Out:
# |--- feature_0 <= 2833.19
# |   |--- feature_0 <= 1913.17
# |   |   |--- feature_0 <= 1226.58
# |   |   |   |--- feature_0 <= 900.83
# |   |   |   |   |--- feature_0 <= 766.31
# |   |   |   |   |   |--- feature_0 <= 742.44
# |   |   |   |   |   |   |--- feature_0 <= 650.13
# |   |   |   |   |   |   |   |--- value: [14.67, 14.38, 14.32, 14.42, 14.51, 14.53, 14.50, 14.44, 14.35, 14.25, 14.14, 14.02, 13.90, 13.77, 13.64, 13.51, 13.38, 13.24, 13.11, 12.99, 12.90, 12.83, 12.78, 12.75, 12.73, 12.72, 12.71, 12.71, 12.71, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70, 12.70]
# |   |   |   |   |   |   |--- feature_0 >  650.13
# |   |   |   |   |   |   |   |--- feature_0 <= 704.92
# |   |   |   |   |   |   |   |   |--- value: [14.70, 14.28, 14.14, 14.21, 14.29, 14.30, 14.27, 14.20, 14.12, 14.02, 13.92, 13.81, 13.70, 13.59, 13.47, 13.35, 13.23, 13.11, 12.99, 12.89, 12.81, 12.76, 12.73, 12.71, 12.69, 12.69, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68, 12.68]
# |   |   |   |   |   |   |   |--- feature_0 >  704.92
# |   |   |   |   |   |   |   |   |--- value: [14.59, 14.34, 14.28, 14.31, 14.32, 14.29, 14.23, 14.15, 14.07, 13.97, 13.88, 13.78, 13.67, 13.57, 13.47, 13.36, 13.26, 13.15, 13.04, 12.95, 12.89, 12.84, 12.81, 12.80, 12.79, 12.78, 12.78, 12.78, 12.78, 12.78, 12.78, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77, 12.77]
# |   |   |   |   |   |--- feature_0 >  742.44
# |   |   |   |   |   |   |--- value: [14.84, 14.60, 14.52, 14.51, 14.48, 14.43, 14.36, 14.28, 14.18, 14.09, 13.99, 13.89, 13.79, 13.69, 13.58, 13.48, 13.37, 13.26, 13.16, 13.07, 13.01, 12.96, 12.94, 12.92, 12.91, 12.91, 12.91, 12.91, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90, 12.90]
# |   |   |   |   |--- feature_0 >  766.31
# |   |   |   |   |   |--- feature_1 <= 9.48
# |   |   |   |   |   |   |--- feature_1 <= 8.99
# |   |   |   |   |   |   |   |--- value: [14.74, 14.40, 14.31, 14.39, 14.47, 14.50, 14.48, 14.43, 14.36, 14.27, 14.18, 14.09, 13.99, 13.89, 13.79, 13.69, 13.58, 13.47, 13.37, 13.28, 13.22, 13.17, 13.15, 13.13, 13.12, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.11, 13.
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.57, 14.49, 14.76, 15.23, 15.75, 16.25, 16.73, 17.18, 17.54, 17.84, 18.08, 18.28, 18.48, 18.72, 18.93, 19.13, 19.29, 19.42, 19.52, 19.59, 19.65, 19.70, 19.74, 19.76, 19.79, 19.85, 19.95, 20.04, 20.10, 20.14, 20.18, 20.22, 20.26, 20.29, 20.32, 20.35, 20.38, 20.40, 20.42, 20.44, 20.45, 20.46, 20.47, 20.48, 20.49, 20.49, 20.50, 20.51, 20.51, 20.52, 20.52, 20.53]
# |   |   |   |   |   |   |--- feature_1 >  17.40
# |   |   |   |   |   |   |   |--- feature_0 <= 5839.52
# |   |   |   |   |   |   |   |   |--- feature_0 <= 5671.56
# |   |   |   |   |   |   |   |   |   |--- value: [15.00, 15.08, 15.37, 15.78, 16.24, 16.70, 17.15, 17.55, 17.90, 18.17, 18.39, 18.65, 18.87, 19.06, 19.25, 19.41, 19.55, 19.68, 19.80, 19.91, 19.98, 20.03, 20.07, 20.09, 20.10, 20.12, 20.14, 20.17, 20.19, 20.21, 20.24, 20.26, 20.29, 20.32, 20.35, 20.38, 20.40, 20.42, 20.44, 20.45, 20.47, 20.48, 20.48, 20.49, 20.50, 20.50, 20.51, 20.51, 20.52, 20.52, 20.52, 20.52]
# |   |   |   |   |   |   |   |   |--- feature_0 >  5671.56
# |   |   |   |   |   |   |   |   |   |--- value: [14.87, 14.95, 15.24, 15.66, 16.13, 16.60, 17.06, 17.48, 17.83, 18.09, 18.31, 18.57, 18.77, 18.99, 19.18, 19.34, 19.48, 19.61, 19.72, 19.81, 19.88, 19.92, 19.95, 19.97, 19.98, 19.99, 20.02, 20.08, 20.15, 20.22, 20.27, 20.31, 20.35, 20.38, 20.41, 20.43, 20.44, 20.46, 20.47, 20.48, 20.49, 20.49, 20.50, 20.50, 20.51, 20.51, 20.51, 20.52, 20.52, 20.52, 20.52, 20.52]
# |   |   |   |   |   |   |   |--- feature_0 >  5839.52
# |   |   |   |   |   |   |   |   |--- value: [14.84, 14.95, 15.27, 15.73, 16.22, 16.72, 17.20, 17.61, 17.94, 18.18, 18.40, 18.64, 18.87, 19.08, 19.26, 19.42, 19.56, 19.67, 19.77, 19.85, 19.90, 19.94, 19.96, 19.98, 20.03, 20.12, 20.22, 20.29, 20.34, 20.39, 20.44, 20.48, 20.51, 20.54, 20.56, 20.58, 20.59, 20.61, 20.62, 20.62, 20.63, 20.63, 20.64, 20.64, 20.65, 20.65, 20.65, 20.65, 20.65, 20.65, 20.65, 20.66]

# %%
#--------------------#
# Plot the residual  #
#------------------––#
# Plot the difference between the water level in the test file and the one predicted by the ML model

residual = y_test - y_pred

# box plot
fig, ax = plt.subplots(figsize=(12, 4))
bplot = ax.boxplot(residual,
                     vert=True,  # vertical box alignment
                     patch_artist=True)  
colors = ['#a7bed3', '#f1ffc4', '#ffcaaf', '#dab894']*13
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)
plt.xlabel('Timestep')
plt.ylabel('Residual [$m$]')
plt.title('Residual between the water level simulated by the physical model \n and the one predicted by Decison Trees model')
plt.show()

# %% [markdown]
# ### <div class="alert-danger">  Q2) Try to train another model on the dataset assuming that the RMSE should not exceed 30cm.  </div>

# %% [markdown]
# # My code to improve the decision tree regressor <a class="anchor" id="improving_decision_tree_regressor"></a>
#
# The above model is completely overfitted, since no restrictions were put on the decision tree. Indeed, if we give a lower bound on the number of samples in each leaf, the RMSE already improves. Setting to this value to 10 seems to be a good starting point.
#
# Reusing some parts of the code above:

# %%
rf = DecisionTreeRegressor(min_samples_leaf = 10)
rf_model = rf.fit(x_train, y_train)

### How good are the predictions?
y_pred = rf_model.predict(x_test)
q2_score = r2_score(y_pred, y_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("The R2 score on test set: {:.4f}".format(q2_score))
print("The root mean squared error (RMSE) on test set: {:.4f} [m]".format(rmse))
# Out:
# The R2 score on test set: 0.8155
# The root mean squared error (RMSE) on test set: 0.2380 [m]

# %% [markdown]
# One can also tune the maximum depth. A useful tool for tuning hyperparameter is <a href="https://www.ray.io/ray-tune">Ray Tune</a>. This library provides a tuner, taking as arguments a trainer function and a dict from which hyperparameters values are picked up.

# %%
from ray import air, tune
from ray.air import session

def DTRtrainer(config):
    rf = DecisionTreeRegressor(min_samples_leaf=config["min_samples_leaf"], max_depth=config["max_depth"])
    rf_model = rf.fit(x_train, y_train)
    
    y_pred = rf_model.predict(x_test)
    q2_score = r2_score(y_pred, y_test)
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    
    # report these metrics to tune
    session.report({
        "q2_score" : q2_score,
        "rmse" : rmse
    })
    
search_space = {
    "min_samples_leaf": tune.randint(2, 30),
    "max_depth": tune.randint(1, 20)
}

tuner = tune.Tuner(
    DTRtrainer,
    param_space = search_space,
    tune_config = tune.TuneConfig(num_samples=50) # number of decision trees to train
    )

results = tuner.fit()

df_results = results.get_dataframe() #results are collected in a dataframe
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-04-24 18:55:48</td></tr>
# <tr><td>Running for: </td><td>00:00:12.32        </td></tr>
# <tr><td>Memory:      </td><td>4.1/15.1 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/6.46 GiB heap, 0.0/3.23 GiB objects
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc               </th><th style="text-align: right;">  max_depth</th><th style="text-align: right;">  min_samples_leaf</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  q2_score</th><th style="text-align: right;">    rmse</th></tr>
# </thead>
# <tbody>
# <tr><td>DTRtrainer_d5a81_00000</td><td>TERMINATED</td><td>192.168.1.26:20887</td><td style="text-align: right;">         11</td><td style="text-align: right;">                 2</td><td style="text-align: right;">     1</td><td style="text-align: right;">      0.0158083 </td><td style="text-align: right;">  0.849373</td><td style="text-align: right;">0.280387</td></tr>
# <tr><td>DTRtrainer_d5a81_00001</td><td>TERMINATED</td><td>192.168.1.26:20951</td><td style="text-align: right;">         15</td><td style="text-align: right;">                 9</td><td style="text-align: right;">     1</td><td style="text-align: right;">      0.0115521 </td><td style="text-align: right;">  0.819218</td><td style="text-align: right;">0.238383</td></tr>
# <tr><td>DTRtrainer_d5a81_00002</td><td>TERMINATED</td><td>192.168.1.26:20953</td><td style="text-align: right;">         11</td><td style="text-align: right;">                27</td><td style="text-align: right;">     1</td><td style="text-align: right;">      0.0188453 </td><td style="text-align: right;">  0.672138</td><td style="text-align: right;">0.246991</td></tr>
# <tr><td>DTRtrainer_d5a81_00003</td><td>TERMINATED</td><td>192.168.1.26:20955</td><td style="text-align: right;">          3</td><td style="text-align: right;">                11</td><td style="text-align: right;">     1</td><td style="text-align: right;">      0
# time_this_iter_s                                                      0.00698
# done                                                                    False
# timesteps_total                                                           NaN
# episodes_total                                                            NaN
# training_iteration                                                          1
# trial_id                                                          d5a81_00005
# experiment_id                                6b171b9ee82f4b9dbbafca4b8d65690f
# date                                                      2023-04-24_18-55-45
# timestamp                                                          1682355345
# time_total_s                                                          0.00698
# pid                                                                     20959
# hostname                                                 martin-ThinkPad-E485
# node_ip                                                          192.168.1.26
# time_since_restore                                                    0.00698
# timesteps_since_restore                                                     0
# iterations_since_restore                                                    1
# warmup_time                                                          0.004812
# config/max_depth                                                            5
# config/min_samples_leaf                                                     2
# logdir                      /home/martin/ray_results/DTRtrainer_2023-04-24...
# Name: 5, dtype: object

# %% [markdown]
# The RMSE value is not substantially improved. The $R^2$ coefficient is worse than before tuning, but this coefficient loses much of its interpretability for nonlinear models.

# %% [markdown]
# # 3) Monthly flow climate data analysis

# %%
#------------------------------------------------------------#
# Load the discharge historical data at a specific location  #
#------------------------------------------------------------#
df = pd.read_csv(os.path.join(path, 'dis_obs_clim.csv')) 
df['month'] = pd.to_datetime(df['month'])
df
# Out:
#          month  dis_observed
# 0   2000-01-01     49.141290
# 1   2000-02-01     63.602069
# 2   2000-03-01     69.980645
# 3   2000-04-01     28.339000
# 4   2000-05-01     28.950323
# ..         ...           ...
# 259 2021-08-01     16.082581
# 260 2021-09-01     13.500000
# 261 2021-10-01     23.997742
# 262 2021-11-01     30.696333
# 263 2021-12-01     52.714194
#
# [264 rows x 2 columns]

# %%
#------------------#
# Describe data    #
#------------------#
df.describe()
# Out:
#        dis_observed
# count    238.000000
# mean      36.476164
# std       22.756222
# min       11.276897
# 25%       19.501917
# 50%       27.838613
# 75%       49.193226
# max      116.681786

# %%
#------------#
# plot data  #
#------------#
plt.figure(100, figsize=(10,5))
df.plot(x='month', y='dis_observed', color = "black")
# Out:
# <AxesSubplot: xlabel='month'>

# %% [markdown]
# Handling missing values highly depends on the nature of the data, the size and location of the gaps, and the intended use of the data. In general, the main common strategies are:
# - Removing rows with missing values.
# - Mark and learn missing values.
# - Mask and learn without missing values.
#
# Try each approach on your sequence prediction problem and double down on what appears to work best.
# Here are some commonly used methods to fill gaps in a time series:
#
# - Forward fill (or backward fill): This method fills the gap with the last (or first) observed value. This method is suitable when the missing values occur in sequences or when the data has a slowly changing trend.
#
# - Linear interpolation: This method fills the gap with a straight line between the last observed value before the gap and the first observed value after the gap. This method is suitable when the data has a linear trend.
#
# - Seasonal interpolation: This method fills the gap with a value that corresponds to the same season or time of day as the missing value. This method is suitable when the data has a seasonal pattern.
#
# - Mean or median imputation: This method fills the gap with the mean or median of the observed values. This method is suitable when the data has a normal distribution.
#
# - Regression imputation: This method uses regression models to predict the missing values based on the relationship between the time series and other relevant variables. This method is suitable when the data has complex patterns or when the gaps are large.

# %% [markdown]
# ## a. Gap filling
# ### a.1) Using Inverse Principal Component Analysis

# %% [markdown]
# Given a time series $X$ of length $n$, with $m$ missing values, IPCA aims to fill in the missing values by decomposing $X$ into its principal components and filling in the missing values in the principal component space. Let $X'$ be the filled-in time series, and let $P$ be the matrix of principal components. Then, IPCA can be expressed as:
#
# $X' = P * diag(eigenvalues) * P^T$,
#
# where diag(eigenvalues) is a diagonal matrix of eigenvalues and $P^T$ is the transpose of $P$.
#
# NB: $m$ should be small.

# %%
#-----------------------------------------#
# Compute the ratio of the missing values # 
#-----------------------------------------#
null_values = df['dis_observed'].isnull()
print('The ratio of missing values is: {:.2f} %'.format(round(sum(null_values)*100/len(df), 2)))
# Out:
# The ratio of missing values is: 9.85 %

# %%
#------------#
# Scale data #
#------------#
scaler = MinMaxScaler(feature_range=(0, 1))
ts_scaled = scaler.fit_transform(np.array(df['dis_observed']).reshape(-1,1))
df['dis_scaled'] = ts_scaled

# %%
#-------------------------------------------#
# Impute missing values with PCA inverse    # 
#-------------------------------------------#
data_month = np.array(ts_scaled).reshape(-1, 12) # reshape data
data = np.where(np.isnan(data_month), np.ma.array(data_month, mask=np.isnan(data_month)).mean(axis=0), data_month) # imputation using the mean to get rid of NaN values so the PCA can be computed
pca = PCA(n_components=0.9)
data_filled = pca.inverse_transform(pca.fit_transform(data))
df['dis_pcai'] = list(data_filled.reshape(-1))
df['dis_filled'] = df['dis_scaled'].fillna(df['dis_pcai'])

### plot the PCA result
plt.figure(100, figsize=(10,5))
df.plot(x='month', y=['dis_filled', 'dis_scaled'], color = ["blue", "black"])
# Out:
# <AxesSubplot: xlabel='month'>

# %% [markdown]
# ### a.2) Gap filling using Multivariate Imputation by Chained Equation

# %% [markdown]
# Multivariate Imputation by Chained Equation (MICE) first calculates the mean of every column where there is a missing value and uses the mean value as a placeholder. Then it runs a series of regression models (chained equations) to impute each missing value sequentially. Like in any regression model, MICE uses a feature matrix and target variable to train, and in this case, the target variable is the column with missing values. MICE predicts and updates missing values on target columns. Iteratively, MICE repeats this process several times by constantly changing the placeholder variables with the predictions from the previous iteration. In the end, it reaches a robust estimation.

# %%
#-------------------------------------------#
# Impute missing values with MICE           # 
#-------------------------------------------#
### Extract the month only (month_) to use it as a predictor for MICE
df['month_'] = [df['month'][x].month for x in range(len(df['month']))]


### Imputing with MICE
df_mice = df.filter(['month_','dis_scaled']).copy()


### Define MICE Imputer and fill missing values
mice_imputer = IterativeImputer(estimator=linear_model.BayesianRidge(), n_nearest_features=None, imputation_order='ascending')

df_mice_imputed = pd.DataFrame(mice_imputer.fit_transform(df_mice), columns=df_mice.columns)

# %%
#-----------------#
#Plot MICE result # 
#-----------------#
fig = plt.Figure() 
fig = df_mice_imputed.plot(x='month_', y='dis_scaled', kind='scatter', c=null_values, cmap='winter', title='MICE Imputation', colorbar=False)

# %%
### Plot result as a time series
df['dis_mice'] = df_mice_imputed['dis_scaled']
plt.figure(100, figsize=(10,5))
df.plot(x='month', y=['dis_scaled', 'dis_filled', 'dis_mice'], color = ["black", "blue", "purple"])
# Out:
# <AxesSubplot: xlabel='month'>

# %% [markdown]
# In the following, we'll consider PCA inverse imputation.

# %% [markdown]
# ## b. Time series forecasting

# %%
### analyze its seasonality
ts_scaled = TimeSeries.from_dataframe(df, 'month', 'dis_filled')
is_seasonal, periodicity = check_seasonality(ts_scaled, max_lag=240)
dict_seas ={
    "is seasonal?":is_seasonal, 
    "periodicity (months)":f'{periodicity:.1f}', 
    "periodicity (~years)": f'{periodicity/12:.1f}'}
_ = [print(k,":",v) for k,v in dict_seas.items()]
# Out:
# is seasonal? : True
# periodicity (months) : 12.0
# periodicity (~years) : 1.0

# %%
### plot its autocorrelation function
plot_acf(ts_scaled, periodicity, max_lag=150)

# %% [markdown]
# Neural Basis Expansion Analysis (NBEA) is a method for time series forecasting that combines neural networks with basis expansion techniques. The basic idea behind NBEA is to use a neural network to learn a mapping between the past values of a time series and its future values, while also using basis expansion techniques to capture non-linear relationships between the time series and its predictors.
#
# NBEA works by first transforming the input time series into a basis-expanded representation, which captures non-linear relationships between the time series and its predictors. This basis-expanded representation is then used as input to a neural network, which learns a mapping between the past values of the time series and its future values. The output of the neural network is then transformed back into the original time series space.
#
# The main advantage of NBEA is that it can capture complex non-linear relationships between the time series and its predictors, while also leveraging the power of neural networks for time series forecasting. NBEA has been shown to be effective for a wide range of time series forecasting tasks, including financial forecasting, environmental forecasting, and traffic forecasting.

# %%
#--------------------------------------------------#
# Forecast the last three years of the time series # 
# using NBEATS model                               #
#--------------------------------------------------#
### Split training vs test dataset
# Let's keep the last 36 months as test
ts_split = -36
train, test = ts_scaled[:ts_split], ts_scaled[ts_split:]

# %% [markdown]
# Let’s look at a first example. We’ll build an N-BEATS model that has a lookback window of 24 points (input_chunk_length=24) and predicts the next 12 points (output_chunk_length=12). We chose these values so that our model will produce successive predictions for one year at a time, looking at the past two years.

# %%
### Define the model parameters
model = NBEATSModel(
    input_chunk_length=24, output_chunk_length=12, n_epochs=50, random_state=1
)

# %%
### Fit the model using the training data 
#--- for n_epochs=50, the training lasts ~2 minutes
nbeats_start_time = time.time()
model.fit(train, verbose=True)
print(f'Training duration time: {time.time() - nbeats_start_time}')
# Out:
# Training: 0it [00:00, ?it/s]
# Training duration time: 58.19436168670654

# %% [markdown]
# We can then get a forecast by calling predict().
#
# Note that below, we are calling predict() with a horizon of 36, which is longer than the model internal output_chunk_length of 12. That’s not a problem here, in such a case the internal model will simply be called auto-regressively on its own outputs. In this case, it will be called three times so that the three 12-points outputs make up the final 36-points forecast - but all of this is done transparently behind the scenes.
#
# MAPE = 'Mean Absolute Percentage Error'

# %%
### Predict the test data 
pred = model.predict(n=36)
ts_scaled.plot(label="actual")
pred.plot(label="forecast")
plt.legend()
print("MAPE = {:.2f}%".format(mape(ts_scaled, pred)))
# Out:
# Predicting: 0it [00:00, ?it/s]
# MAPE = 279.21%

# %% [markdown]
# Some options could be investigated to optimize the model:
# - *Increase the number of epochs:* An epoch is one full pass through the training data, and increasing the number of epochs allows the model to see the training data more times and refine its weights accordingly. However, increasing the number of epochs beyond a certain point can lead to overfitting, where the model becomes too specialized to the training data and performs poorly on new data. Therefore, it's important to find the optimal number of epochs that balances between the underfitting and overfitting. This can be done by monitoring the validation loss while training the model and stopping the training when the validation loss starts to increase.
#
# - *Increase the size of the model:* The NBEATSModel consists of several fully connected layers, and increasing the size of the model can help to increase its capacity and improve its performance. You can try adding more layers or increasing the number of units in each layer.
#
# - *Adjust the learning rate:* The learning rate determines how much the weights of the model are updated during each iteration of training. If the learning rate is too high, the model may overshoot the optimal weights and fail to converge. If the learning rate is too low, the model may take a long time to converge. You can try adjusting the learning rate to find the optimal value.
#
# - *Add regularization:* Regularization techniques such as L1 or L2 regularization, dropout, or early stopping can help to prevent overfitting and improve the generalization performance of the model. You can try adding one or more of these techniques to the model.
#
# - *Use a different optimizer:* The optimizer is responsible for updating the weights of the model during training. Different optimizers have different strengths and weaknesses, and choosing the right optimizer can help to improve the performance of the model. You can try using a different optimizer, such as Adam or RMSprop, to see if it improves the performance.
#
# - *Increase the amount of training data:* Deep learning models require a large amount of data to learn complex patterns effectively. If you have a small amount of training data, you can try augmenting the data by applying transformations such as rotation, translation, or scaling. This can help to increase the size of the training set and improve the performance of the model.

# %% [markdown]
# Now, we used Darts to obtain one forecast over the next 36 months starting in January 2019. However, forecasts often need to be updated as soon as new data becomes available. With Darts, it’s easy to compute the forecasts resulting from such a process, using backtesting. Backtesting refers to the process of evaluating the performance of a forecasting model on historical data.
#
# - Prophet is a forecasting technique developed by Facebook that uses an additive model to decompose a time series into its underlying components such as trend, seasonality, holidays, and outliers. The model uses a Bayesian framework to estimate the parameters and can handle missing data and irregularly spaced time series.
#
# - Exponential Smoothing is a family of forecasting methods that uses a weighted average of past observations to forecast future values. The weights assigned to past observations decay exponentially as the observations get older.

# %%
### Backtesting 
models = [ExponentialSmoothing(), Prophet()]

backtests = [model.historical_forecasts(ts_scaled,
                            start=.8571, # the split is given as a percentage
                            forecast_horizon=3) # three months forecast horizon 
             for model in models]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 4
#       1 ### Backtesting
#       2 models = [ExponentialSmoothing(), Prophet()]
# ----> 4 backtests = [model.historical_forecasts(ts_scaled,
#       5                             start=.8571, # the split is given as a percentage
#       6                             forecast_horizon=3) # three months forecast horizon
#       7              for model in models]
#
# Cell In[29], line 4, in <listcomp>(.0)
#       1 ### Backtesting
#       2 models = [ExponentialSmoothing(), Prophet()]
# ----> 4 backtests = [model.historical_forecasts(ts_scaled,
#       5                             start=.8571, # the split is given as a percentage
#       6                             forecast_horizon=3) # three months forecast horizon
#       7              for model in models]
#
# File ~/anaconda3/lib/python3.9/site-packages/darts/utils/utils.py:179, in _with_sanity_checks.<locals>.decorator.<locals>.sanitized_method(self, *args, **kwargs)
#     176     only_args.pop("self")
#     178     getattr(self, sanity_check_method)(*only_args.values(), **only_kwargs)
# --> 179 return method_to_sanitize(self, *only_args.values(), **only_kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/forecasting_model.py:1050, in ForecastingModel.historical_forecasts(self, series, past_covariates, future_covariates, num_samples, train_length, start, forecast_horizon, stride, retrain, overlap_end, last_points_only, verbose, show_warnings)
#    1041 if retrain_func(
#    1042     counter=_counter_train,
#    1043     pred_time=pred_time,
#    (...)
#    1047 ):
#    1048     # avoid fitting the same model multiple times
#    1049     model = model.untrained_model()
# -> 1050     model._fit_wrapper(
#    1051         series=train_series,
#    1052         past_covariates=past_covariates_,
#    1053         future_covariates=future_covariates_,
#    1054     )
#    1055 else:
#    1056     # untrained model was not trained on the first trainable timestamp
#    1057     if not _counter_train and not model._fit_called:
#
# File ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/forecasting_model.py:286, in ForecastingModel._fit_wrapper(self, series, past_covariates, future_covariates)
#     280 def _fit_wrapper(
#     281     self,
#     282     series: TimeSeries,
#     283     past_covariates: Optional[TimeSeries],
#     284     future_covariates: Optional[TimeSeries],
#     285 ):
# --> 286     self.fit(series)
#
# File ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/exponential_smoothing.py:106, in ExponentialSmoothing.fit(self, series)
#      95     seasonal_periods_param = 12
#      97 hw_model = hw.ExponentialSmoothing(
#      98     series.values(copy=False),
#      99     trend=self.trend if self.trend is None else self.trend.value,
#    (...)
#     104     dates=series.time_index if series.has_datetime_index else None,
#     105 )
# --> 106 hw_results = hw_model.fit(**self.fit_kwargs)
#     107 self.model = hw_results
#     109 if self.infer_seasonal_periods:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:1141, in ExponentialSmoothing.fit(self, smoothing_level, smoothing_trend, smoothing_seasonal, damping_trend, optimized, remove_bias, start_params, method, minimize_kwargs, use_brute, use_boxcox, use_basinhopping, initial_level, initial_trend)
#    1139 method = "SLSQP" if method is None else method
#    1140 if optimized:
# -> 1141     res = self._optimize_parameters(
#    1142         res, use_brute, method, minimize_kwargs
#    1143     )
#    1144 else:
#    1145     l0, b0, s0 = self.initial_values(
#    1146         initial_level=initial_level, initial_trend=initial_trend
#    1147     )
#
# File ~/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:837, in ExponentialSmoothing._optimize_parameters(self, data, use_brute, method, kwargs)
#     833 bounds = np.array(orig_bounds[:3], dtype=float)
#     834 hw_args = HoltWintersArgs(
#     835     sel.astype(int), params, bounds, y, m, self.nobs
#     836 )
# --> 837 params = self._get_starting_values(
#     838     params,
#     839     start_params,
#     840     use_brute,
#     841     sel,
#     842     hw_args,
#     843     bounds,
#     844     init_alpha,
#     845     func,
#     846 )
#     848 # We always use [0, 1] for a, b and g and handle transform inside
#     849 mod_bounds = [(0, 1)] * 3 + orig_bounds[3:]
#
# File ~/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:743, in ExponentialSmoothing._get_starting_values(self, params, start_params, use_brute, sel, hw_args, bounds, alpha, func)
#     741 best_params = points[0]
#     742 for point in points:
# --> 743     val = opt(point, hw_args)
#     744     if val < best_val:
#     745         best_params = point
#
# File ~/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:81, in opt_wrapper.<locals>.f(*args, **kwargs)
#      80 def f(*args, **kwargs):
# ---> 81     err = func(*args, **kwargs)
#      82     if isinstance(err, np.ndarray):
#      83         return err.T @ err
#
# KeyboardInterrupt:

# %% [markdown]
# The function historical_forecasts() takes a time series, a starting point (here, 85% of the time series) and a forecast horizon. It returns the TimeSeries containing the historical forecasts that would have been obtained when using the model to forecast the series with the specified forecast horizon (here 3 months), starting at the specified timestamp (using an expanding window strategy).

# %%
#--------------------------------------------------#
# Forecast the last three years of the time series # 
# using backtesting process                        #
#--------------------------------------------------#
models_str = ['ExponentialSmoothing', 'Prophet']
ts_scaled.plot(label='data')
for i, m in enumerate(models_str):
    err = mape(backtests[i], ts_scaled)
    backtests[i].plot(lw=3, label='{}, MAPE={:.2f}%'.format(m, err))

plt.title('Backtests with 3-months forecast horizon')
plt.legend()

# %% [markdown]
# Backtesting forecasting models — here we simulate making forecasts with a 3 months horizon, every month starting in January 2019 (so the first forecast value is for April 2019).

# %% [markdown]
# ### <div class="alert-danger">  Q3) Try to optimize these models using one of the different techniques listed above.  </div>

# %% [markdown]
# # My code to handle the missing values <a class="anchor" id="handling_missing_values"></a>
#
# We first try the different propositions to handle the missing values in the data. The NBEAST model is trained on each of these data sets, in order to see which yields the best result. We include the data produced with the MICE procedure.
#
# We first create the columns of the <code>df</code> dataframe with the corresponding data (already scaled):

# %%
# forward fill
df['dis_ffill'] = df['dis_scaled'].fillna(method='ffill')
# backward fill
df['dis_bfill'] = df['dis_scaled'].fillna(method='bfill')
# linear interpolation
df['dis_lin_interp'] = df['dis_scaled'].interpolate(method='index')

# Seasonal interpolation: replace the value by the mean of values of the same month
monthly_means = df.groupby('month_').mean()
idx_missing_dis_scaled = df['dis_scaled'].isna()
df['dis_seasonal_interp'] = df['dis_scaled']
df['dis_seasonal_interp'][idx_missing_dis_scaled] = monthly_means['dis_scaled'][df['month_'][idx_missing_dis_scaled]]

fill_methods=['_ffill', '_bfill', '_lin_interp', '_seasonal_interp', '_mice']
for fill_method in fill_methods:
    df.plot(x='month', y=['dis'+fill_method, 'dis_scaled'], color = ["blue", "black"])
    plt.show()

# %%
# Create the TimeSeries of each set of data, collecting them in a dict
ts_scaled_dict = {}

for fill_method in fill_methods:
    ts_scaled_dict[fill_method] = TimeSeries.from_dataframe(df, 'month', 'dis'+fill_method)
    plot_acf(ts_scaled_dict[fill_method], periodicity, max_lag=150)
    plt.title('dis'+fill_method)

# %%
# Split each data set into training and test sets
ts_split = -36

train_dict={}
test_dict={}

for fill_method in fill_methods :
    train_dict[fill_method] = ts_scaled_dict[fill_method][:ts_split]
    test_dict[fill_method] = ts_scaled_dict[fill_method][ts_split:]

# %%
# train the model on each data set to see on which it performs best
for fill_method in fill_methods:    
    model = NBEATSModel(
        input_chunk_length=24,
        output_chunk_length=12,
        n_epochs=50,
        random_state=1,
    )

    model.fit(train_dict[fill_method], verbose=True)

    pred = model.predict(n=36)
    ts_scaled_dict[fill_method].plot(label="actual")
    pred.plot(label="forecast")
    plt.legend()
    plt.title('Forecast using ' + fill_method + ' as fill method')
    print("MAPE = {:.2f}%".format(mape(ts_scaled_dict[fill_method], pred)))
    plt.show()

# %% [markdown]
# The backward-fill and the seasonal interpolation methods give the best results (smaller MAPE scores). We keep these two datasets in the following.

# %% [markdown]
# # My code to optimize the NBEATS model <a class="anchor" id="NBEATS"></a>
#
# We now turn to the optimization of the NBEATS model by tuning its hyperparameter. As can be checked in the <a href="https://unit8co.github.io/darts/generated_api/darts.models.forecasting.nbeats.html">documentation</a>, the NBEATS model is a fully connected neural network and we will tune it by playing on the following aspects:
#  - a way to stop training when it is completed
#  - the number of layers
#  - the width, i.e. the number of neurons in each layer
#  - the learning rate
#  - an eventual regularization
#
# Let us first define two useful callbacks from Pytorch Lightning. EarlyStopping stops the training whenever the train loss has not decreased more than 0.002 for 5 epochs, while the LossLogger class stores the train and loss.

# %%
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.callbacks import Callback

class StopperTrain(EarlyStopping):
    def __init__(self):
        super().__init__(
        monitor = "train_loss",
        patience = 5,
        min_delta = 0.002,
        mode = 'min'
        )
    
class LossLogger(Callback):
    def __init__(self):
        self.train_loss = []
        self.val_loss = []

    def on_train_epoch_end(self, trainer: "pl.Trainer", pl_module: "pl.LightningModule") -> None:
        self.train_loss.append(float(trainer.callback_metrics["train_loss"]))
    
    def on_validation_epoch_end(self, trainer: "pl.Trainer", pl_module: "pl.LightningModule") -> None:
        self.val_loss.append(float(trainer.callback_metrics["val_loss"]))

# %% [markdown]
# We also define the model configuration to tune. The training is expected to be stopped by the EarlyStopping callback, which is why the number of epochs is set to a high enough number. Above, the batch size was left to its default value of 32, but this makes the training loss to oscillate much more, and is then more difficult to monitor with the EarlyStopping callback. Since the training does not seem to be that slower with only one batch, we set the batch size to the length of the training timeseries (i.e. 228).

# %%
def NBEATSToTune(num_layers = None, layer_widths = None, learning_rate = None, weight_decay = None):
    pl_trainer_kwargs = {'callbacks':[StopperTrain(), LossLogger()]}
    model=NBEATSModel(
        input_chunk_length = 24,
        output_chunk_length = 12,
        n_epochs = 100,
        num_layers = num_layers,
        layer_widths = layer_widths,
        random_state = 1,
        pl_trainer_kwargs = pl_trainer_kwargs,
        optimizer_kwargs = {'lr': learning_rate, 'weight_decay': weight_decay},
        force_reset = True,
        batch_size=228,
        )
    model.loss_logger=pl_trainer_kwargs['callbacks'][1]
    return model

# %% [markdown]
# Suitable learning rate and parameters for the EarlyStopping callback can be found quickly after little hand-tuning, by inspecting the training curve.
#
# Now we check how is doing the model with the default architecture (4 layers and 256 neurons in each layer). Note that we use for this the metric used for training, which is the mean square error by default in the NBEATSModel class, instead of the MAPE metric used above.

# %%
for fill_method in ['_bfill', '_seasonal_interp']:
    
    model = NBEATSToTune(
        num_layers = 4,
        layer_widths = 256,
        learning_rate = 2e-3,
        weight_decay = 0
        )
    
    model.fit(train_dict[fill_method], val_series = test_dict[fill_method], verbose=True)
    
    # plot loss from epoch 15 (loss is very quickly decreasing at the beginning)
    plt.plot(loss_logger.train_loss[15:])
    plt.title('Loss for training with ' + fill_method +' data')
    plt.show()
    
    # get validation loss at the end of training for future comparison
    print('val_loss', model.loss_logger.val_loss[-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 6
#       3 stopper_train = StopperTrain()
#       4 loss_logger = LossLogger()
# ----> 6 model = NBEATSToTune(
#       7     num_layers = 4,
#       8     layer_widths = 256,
#       9     learning_rate = 2e-3,
#      10     weight_decay = 0
#      11     )
#      13 model.fit(train_dict[fill_method], val_series = test_dict[fill_method], verbose=True)
#      15 # plot loss from epoch 15 (loss is very quickly decreasing at the beginning)
#
# File ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/forecasting_model.py:103, in ModelMeta.__call__(cls, *args, **kwargs)
#     100 cls._model_call = all_params
#     102 # 6) call model
# --> 103 return super().__call__(**all_params)
#
# Cell In[53], line 32, in NBEATSToTune.__init__(self, num_layers, layer_widths, learning_rate, weight_decay)
#      20 def __init__(self, num_layers = None, layer_widths = None, learning_rate = None, weight_decay = None):
#      21     super().__init__(input_chunk_length = 24,
#      22                     output_chunk_length = 12,
#      23                     n_epochs = 100,
#    (...)
#      30                     pl_trainer_kwargs = {'callbacks':[StopperTrain(), LossLogger()]}
#      31                     )
# ---> 32     self.input_chunk_length=24
#
# AttributeError: can't set attribute

# %% [markdown]
# This model performs already quite well! This could be expected, since the widths of the layers is here 256, which is larger than the <code>input_chunk_length = 24</code> and the size of our trainig set of 228.
#
# Since the model performs quite well, we will look for a smaller model performing about the same.
#
# Define first the model trainer function:

# %%
from ray import air, tune
from ray.air import session

def model_trainer(config, train_set=None, test_set=None):
    
    model = NBEATSToTune(
        num_layers = 4,
        layer_widths = 256,
        learning_rate = 2e-3,
        weight_decay = 0
        )
    
    model.fit(train_set, val_series = test_set, verbose=True)
    
    # report the performance of the trained model to tune
    session.report({'train_loss': loss_logger.train_loss[-1],
                    'val_loss': loss_logger.val_loss[-1]
                   })

# %% [markdown]
# We look for model of 2, 3 or 4 layers with between 64 and 256 neurons in each layer. There is small number of possibilities, so we set <code>tune</code> in grid search mode. The grid search is done for the two filling methods (backward fill and seasonal interpolation).

# %%
search_space = {
    'num_layers' : tune.grid_search([2, 3, 4]),
    'layer_widths' : tune.grid_search([64, 96, 128, 192, 256]),
    }

# dict to store the results
tuner_results_dict={}
 
for fill_method in ['_bfill', '_seasonal_interp']:
    tuner = tune.Tuner(
        tune.with_parameters(model_trainer,
                             train_set = train_dict[fill_method],
                             test_set = test_dict[fill_method]
                            ),
        param_space=search_space,
        tune_config=tune.TuneConfig(mode='min', metric='train_loss'),
        )

    results = tuner.fit()

    tuner_results_dict[fill_method] = results.get_dataframe()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-04-25 21:15:10</td></tr>
# <tr><td>Running for: </td><td>00:01:39.73        </td></tr>
# <tr><td>Memory:      </td><td>4.8/15.1 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/6.04 GiB heap, 0.0/3.02 GiB objects
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name               </th><th>status    </th><th>loc               </th><th style="text-align: right;">  layer_widths</th><th style="text-align: right;">  num_layers</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  val_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>model_trainer_43e59_00000</td><td>TERMINATED</td><td>192.168.1.26:62006</td><td style="text-align: right;">            64</td><td style="text-align: right;">           2</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.85107</td><td style="text-align: right;">   0.0816447</td><td style="text-align: right;"> 0.0606552</td></tr>
# <tr><td>model_trainer_43e59_00001</td><td>TERMINATED</td><td>192.168.1.26:62089</td><td style="text-align: right;">            96</td><td style="text-align: right;">           2</td><td style="text-align: right;">     1</td><td style="text-align: right;">         2.73277</td><td style="text-align: right;">   0.0323592</td><td style="text-align: right;"> 0.0164279</td></tr>
# <tr><td>model_trainer_43e59_00002</td><td>TERMINATED</td><td>192.168.1.26:62187</td><td style="text-align: right;">           128</td><td style="text-align: right;">           2</td><td style="text-align: right;">     1</td><td style="text-align: right;">         5
# <tr><td>model_trainer_43e59_00014</td><td>TERMINATED</td><td>192.168.1.26:62299</td><td style="text-align: right;">           256</td><td style="text-align: right;">           4</td><td style="text-align: right;">     1</td><td style="text-align: right;">        40.6136 </td><td style="text-align: right;">   0.0231993</td><td style="text-align: right;"> 0.0180471</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (model_trainer pid=62006) GPU available: False, used: False
# (model_trainer pid=62006) TPU available: False, using: 0 TPU cores
# (model_trainer pid=62006) IPU available: False, using: 0 IPUs
# (model_trainer pid=62006) HPU available: False, using: 0 HPUs
# (model_trainer pid=62006)
# (model_trainer pid=62006)   | Name          | Type             | Params
# (model_trainer pid=62006) ---------------------------------------------------
# (model_trainer pid=62006) 0 | criterion     | MSELoss          | 0
# (model_trainer pid=62006) 1 | train_metrics | MetricCollection | 0
# (model_trainer pid=62006) 2 | val_metrics   | MetricCollection | 0
# (model_trainer pid=62006) 3 | stacks        | ModuleList       | 198 K
# (model_trainer pid=62006) ---------------------------------------------------
# (model_trainer pid=62006) 198 K     Trainable params
# (model_trainer pid=62006) 469       Non-trainable params
# (model_trainer pid=62006) 198 K     Total params
# (model_trainer pid=62006) 0.795     Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  4.46it/s, train_loss=2.130]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  4.15it/s, train_loss=2.130, val_loss=0.804]
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=2.130, val_loss=0.804]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00, 13.35it/s, train_loss=0.758, val_loss=0.804]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00, 11.62it/s, train_loss=0.758, val_loss=0.154]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.758, val_loss=0.154]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00, 14.82it/s, train_loss=0.146, val_loss=0.154]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00, 12.86it/s, train_loss=0.146, val_loss=0.110]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.146, val_loss=0.110]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00, 10.36it/s, train_loss=0.215, val_loss=0.110]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00,  9.04it/s, train_loss=0.215, val_loss=0.233]
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.215, val_loss=0.233]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00,  6.49it/s, train_loss=0.390, val_loss=0.233]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00,  5.78it/s, train_loss=0.390, val_loss=0.204]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.390, val_loss=0.204]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00,  9.27it/s, train_loss=0.321, val_loss=0.204]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00,  7.95it/s, train_loss=0.321, val_loss=0.120]
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.321, val_loss=0.120]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 11.98it/s, train_loss=0.180, val_loss=0.120]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 10.17it/s, train_loss=0.180, val_loss=0.0671]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 13.42it/s, train_loss=0.0891, val_loss=0.0671]
# Validation: 0it [00:00, ?it/s])
# (model_trainer pid=62006)
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (model_trainer pid=62006)
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 11.66it/s, train_loss=0.0891, val_loss=0.0617]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 14.86it/s, train_loss=0.0649, val_loss=0.0617]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 12.61it/s, train_loss=0.0649, val_loss=0.0823]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0649, val_loss=0.0823]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 14.64it/s, train_loss=0.0795, val_loss=0.0823]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 12.54it/s, train_loss=0.0795, val_loss=0.102]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0795, val_loss=0.102]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 15.27it/s, train_loss=0.0989, val_loss=0.102]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 13.05it/s, train_loss=0.0989, val_loss=0.108]
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0989, val_loss=0.108]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 13.98it/s, train_loss=0.106, val_loss=0.108]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 11.47it/s, train_loss=0.106, val_loss=0.0997]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.106, val_loss=0.0997]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 10.63it/s, train_loss=0.0985, val_loss=0.0997]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00,  8.99it/s, train_loss=0.0985, val_loss=0.082]
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0985, val_loss=0.082]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00,  9.04it/s, train_loss=0.0816, val_loss=0.082]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00,  7.80it/s, train_loss=0.0816, val_loss=0.0607]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00,  7.57it/s, train_loss=0.0816, val_loss=0.0607]
# (model_trainer pid=62089) GPU available: False, used: False
# (model_trainer pid=62089) TPU available: False, using: 0 TPU cores
# (model_trainer pid=62089) IPU available: False, using: 0 IPUs
# (model_trainer pid=62089) HPU available: False, using: 0 HPUs
# (model_trainer pid=62089)
# (model_trainer pid=62089)   | Name          | Type             | Params
# (model_trainer pid=62089) ---------------------------------------------------
# (model_trainer pid=62089) 0 | criterion     | MSELoss          | 0
# (model_trainer pid=62089) 1 | train_metrics | MetricCollection | 0
# (model_trainer pid=62089) 2 | val_metrics   | MetricCollection | 0
# (model_trainer pid=62089) 3 | stacks        | ModuleList       | 386 K
# (model_trainer pid=62089) ---------------------------------------------------
# (model_trainer pid=62089) 386 K     Trainable params
# (model_trainer pid=62089) 629       Non-trainable params
# (model_trainer pid=62089) 386 K     Total params
# (model_trainer pid=62089) 1.548     Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  6.65it/s, train_loss=1.040]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  6.15it/s, train_loss=1.040, val_loss=0.209]
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=1.040, val_loss=0.209]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  9.48it/s, train_loss=0.193, val_loss=0.209]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  8.36it/s, train_loss=0.193, val_loss=0.212]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.193, val_loss=0.212]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  9.60it/s, train_loss=0.312, val_loss=0.212]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (model_trainer pid=62089)
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  8.53it/s, train_loss=0.312, val_loss=0.145]
#
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  8.39it/s, train_loss=0.312, val_loss=0.145]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.312, val_loss=0.145]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00, 10.74it/s, train_loss=0.227, val_loss=0.145]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00,  9.37it/s, train_loss=0.227, val_loss=0.0584]
#
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.227, val_loss=0.0584]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00,  8.19it/s, train_loss=0.094, val_loss=0.0584]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00,  7.35it/s, train_loss=0.094, val_loss=0.0546]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.094, val_loss=0.0546]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 11.70it/s, train_loss=0.0638, val_loss=0.0546]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 10.30it/s, train_loss=0.0638, val_loss=0.0886]
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0638, val_loss=0.0886]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 12.03it/s, train_loss=0.0898, val_loss=0.0886]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 10.62it/s, train_loss=0.0898, val_loss=0.0973]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 12.63it/s, train_loss=0.104, val_loss=0.0973]
# (model_trainer pid=62089)
# Validation: 0it [00:00, ?it/s])
# (model_trainer pid=62089)
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (model_trainer pid=62089)
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 10.97it/s, train_loss=0.104, val_loss=0.0707]
#
# Epoch 8:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.104, val_loss=0.0707]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 11.17it/s, train_loss=0.0861, val_loss=0.0707]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00,  9.94it/s, train_loss=0.0861, val_loss=0.0341]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0861, val_loss=0.0341]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 11.91it/s, train_loss=0.056, val_loss=0.0341]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 10.33it/s, train_loss=0.056, val_loss=0.0155]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.056, val_loss=0.0155]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 12.17it/s, train_loss=0.0397, val_loss=0.0155]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 10.53it/s, train_loss=0.0397, val_loss=0.0239]
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0397, val_loss=0.0239]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 13.03it/s, train_loss=0.0455, val_loss=0.0239]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 11.40it/s, train_loss=0.0455, val_loss=0.0379]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0455, val_loss=0.0379]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 11.87it/s, train_loss=0.0561, val_loss=0.0379]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 10.37it/s, train_loss=0.0561, val_loss=0.037]
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0561, val_loss=0.037]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00, 10.96it/s, train_loss=0.0546, val_loss=0.037]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00,  9.69it/s, train_loss=0.0546, val_loss=0.0255]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0546, val_loss=0.0255]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 12.00it/s, train_loss=0.0437, val_loss=0.0255]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 10.44it/s, train_loss=0.0437, val_loss=0.0159]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0437, val_loss=0.0159]
# Epoch 15: 100%|██████████| 1/1 [00:00<00:00, 10.49it/s, train_loss=0.0345, val_loss=0.0159]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|██████████| 1/1 [00:00<00:00,  8.34it/s, train_loss=0.0345, val_loss=0.0145]
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0345, val_loss=0.0145]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 11.16it/s, train_loss=0.0318, val_loss=0.0145]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00,  9.00it/s, train_loss=0.0318, val_loss=0.0191]
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0318, val_loss=0.0191]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00, 12.45it/s, train_loss=0.0336, val_loss=0.0191]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00, 10.97it/s, train_loss=0.0336, val_loss=0.0249]
# Epoch 18:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0336, val_loss=0.0249]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00, 11.75it/s, train_loss=0.0364, val_loss=0.0249]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00, 10.30it/s, train_loss=0.0364, val_loss=0.0284]
# Epoch 19:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0364, val_loss=0.0284]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00, 10.35it/s, train_loss=0.0374, val_loss=0.0284]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00,  9.16it/s, train_loss=0.0374, val_loss=0.0274]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0374, val_loss=0.0274]
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 11.30it/s, train_loss=0.0359, val_loss=0.0274]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 10.03it/s, train_loss=0.0359, val_loss=0.0224]
# Epoch 21:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0359, val_loss=0.0224]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 12.18it/s, train_loss=0.0324, val_loss=0.0224]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 10.10it/s, train_loss=0.0324, val_loss=0.0164]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00,  9.83it/s, train_loss=0.0324, val_loss=0.0164]
# (model_trainer pid=62187) GPU available: False, used: False
# (model_trainer pid=62187) TPU available: False, using: 0 TPU cores
# (model_trainer pid=62187) IPU available: False, using: 0 IPUs
# (model_trainer pid=62187) HPU available: False, using: 0 HPUs
# (model_trainer pid=62187)
# (model_trainer pid=62187)   | Name          | Type             | Params
# (model_trainer pid=62187) ---------------------------------------------------
# (model_trainer pid=62187) 0 | criterion     | MSELoss          | 0
# (model_trainer pid=62187) 1 | train_metrics | MetricCollection | 0
# (model_trainer pid=62187) 2 | val_metrics   | MetricCollection | 0
# (model_trainer pid=62187) 3 | stacks        | ModuleList       | 636 K
# (model_trainer pid=62187) ---------------------------------------------------
# (model_trainer pid=62187) 635 K     Trainable params
# (model_trainer pid=62187) 789       Non-trainable params
# (model_trainer pid=62187) 636 K     Total params
# (model_trainer pid=62187) 2.546     Total estimated model params size (MB)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  6.88it/s, train_loss=3.950]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  6.22it/s, train_loss=3.950, val_loss=0.977]
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=3.950, val_loss=0.977]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  7.56it/s, train_loss=0.939, val_loss=0.977]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  6.86it/s, train_loss=0.939, val_loss=0.327]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.939, val_loss=0.327]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  4.27it/s, train_loss=0.259, val_loss=0.327]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  3.98it/

# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00,  1.80it/s, train_loss=0.0208, val_loss=0.0133]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0208, val_loss=0.0133]
# Epoch 25: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s, train_loss=0.0202, val_loss=0.0133]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 25: 100%|██████████| 1/1 [00:00<00:00,  1.72it/s, train_loss=0.0202, val_loss=0.0135]
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0202, val_loss=0.0135]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00,  1.89it/s, train_loss=0.0208, val_loss=0.0135]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00,  1.81it/s, train_loss=0.0208, val_loss=0.0143]
# Epoch 27:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0208, val_loss=0.0143]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00,  1.74it/s, train_loss=0.0208, val_loss=0.0143]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00,  1.68it/s, train_loss=0.0208, val_loss=0.0143]
# Epoch 28:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0208, val_loss=0.0143]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00,  1.90it/s, train_loss=0.0199, val_loss=0.0143]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00,  1.83it/s, train_loss=0.0199, val_loss=0.0134]
# Epoch 29:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0199, val_loss=0.0134]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00,  1.18it/s, train_loss=0.0185, val_loss=0.0134]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00,  1.15it/s, train_loss=0.0185, val_loss=0.0127]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0185, val_loss=0.0127]
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00,  1.97it/s, train_loss=0.0178, val_loss=0.0127]
# (model_trainer pid=64432)
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (model_trainer pid=64432)
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00,  1.85it/s, train_loss=0.0178, val_loss=0.0134]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0178, val_loss=0.0134]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00,  1.40it/s, train_loss=0.0181, val_loss=0.0134]
# (model_trainer pid=64432)
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00,  1.35it/s, train_loss=0.0181, val_loss=0.015]
# Epoch 32:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0181, val_loss=0.015]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s, train_loss=0.0183, val_loss=0.015]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00,  1.86it/s, train_loss=0.0183, val_loss=0.0161]
# Epoch 33:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0183, val_loss=0.0161]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s, train_loss=0.0176, val_loss=0.0161]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s, train_loss=0.0176, val_loss=0.0165]
# Epoch 34:   0%|          | 0/1 [00:00<?, ?it/s, train_loss=0.0176, val_loss=0.0165]
# Epoch 34: 100%|██████████| 1/1 [00:01<00:00,  1.30s/it, train_loss=0.0167, val_loss=0.0165]
# Validation: 0it [00:00, ?it/s])
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 34: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it, train_loss=0.0167, val_loss=0.0167]
# Epoch 34: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it, train_loss=0.0167, val_loss=0.0167]

# %% [markdown]
# We extract now the configurations for which the train loss was below 0.03.

# %%
for fill_method in ['_bfill', '_seasonal_interp']:
    print(fill_method)
    print(tuner_results_dict[fill_method][tuner_results_dict[fill_method].train_loss<0.03]
          [['train_loss', 'val_loss', 'config/layer_widths', 'config/num_layers']])
# Out:
# _bfill
#     train_loss  val_loss  config/layer_widths  config/num_layers
# 2     0.026763  0.023351                  128                  2
# 3     0.023633  0.022634                  192                  2
# 4     0.027507  0.019992                  256                  2
# 7     0.028859  0.017651                  128                  3
# 8     0.024121  0.016314                  192                  3
# 9     0.010203  0.048687                  256                  3
# 12    0.027632  0.015149                  128                  4
# 14    0.023199  0.018047                  256                  4
# _seasonal_interp
#     train_loss  val_loss  config/layer_widths  config/num_layers
# 1     0.023887  0.012996                   96                  2
# 2     0.019108  0.020503                  128                  2
# 3     0.016234  0.015468                  192                  2
# 4     0.018687  0.014651                  256                  2
# 7     0.018413  0.017917                  128                  3
# 8     0.016161  0.014669                  192                  3
# 9     0.016037  0.021166                  256                  3
# 11    0.020660  0.013611                   96                  4
# 12    0.018763  0.014740                  128                  4
# 13    0.021151  0.018429                  192                  4
# 14    0.016710  0.016668                  256                  4

# %% [markdown]
# The smallest architectures performing well enough (train loss below 0.03) in both cases is thus that with 2 layers of 128 neurons each. Since the model generalizes well to the test data (<code>val_loss</code> is of the same order than the train loss), there is no need for a regularization here.
